# %%
from main import main
import matplotlib.pyplot as plt

profit_lsts = main()
print(len(profit_lsts))
for enum, lst in enumerate(profit_lsts):
    plt.figure(figsize=(8, 6), dpi=200)
    plt.plot(range(len(lst)), lst, linewidth=.6)
    plt.xlabel("Iteracja", fontsize=16)
    plt.ylabel("Zysk", fontsize=16)
    plt.title("Rozwiązanie początkowe numer: {}".format(enum))
    ymax = max(lst)
    xmax = lst.index(ymax)
    plt.plot(xmax, ymax, marker='o', markersize=3, label="x={}, y={:.2f}".format(xmax, ymax))
    plt.legend(loc='lower right')
    plt.savefig('visuals/SA/init_pop{}'.format(enum))
    plt.show()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Day 1
# harvested: [17, 17, 17, 17]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [17, 17, 17, 17]
# warehouse: [0, 0, 0, 0]
#
# Day 2
# harvested: [17, 17, 17, 17]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [17, 17, 17, 17]
# warehouse: [0, 0, 0, 0]
#
# Day 3
# harvested: [17, 17, 17, 17]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [17, 17, 17, 17]
# warehouse: [0, 0, 0, 0]
#
# Day 4
# harvested: [17, 17, 17, 17]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [17, 17, 17, 17]
# warehouse: [0, 0, 0, 0]
#
# Day 5
# harvested: [17, 17, 17, 17]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [17, 17, 17, 17]
# warehouse: [0, 0, 0, 0]
#
# Day 6
# harvested: [17, 17, 17, 17]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [17, 17, 17, 17]
# warehouse: [0, 0, 0, 0]
#
# Day 7
# harvested: [17, 17, 17, 17]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [17, 17, 17, 17]
# warehouse: [0, 0, 0, 0]
#
# Day 8
# harvested: [12, 12, 12, 12]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [12, 12, 12, 12]
# warehouse: [0, 0, 0, 0]
#
# Day 9
# harvested: [12, 12, 12, 12]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [12, 12, 12, 12]
# warehouse: [0, 0, 0, 0]
#
# Day 10
# harvested: [12, 12, 12, 12]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [12, 12, 12, 12]
# warehouse: [0, 0, 0, 0]
#
# Day 11
# harvested: [12, 12, 12, 12]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [12, 12, 12, 12]
# warehouse: [0, 0, 0, 0]
#
# Day 12
# harvested: [12, 12, 12, 12]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [12, 12, 12, 12]
# warehouse: [0, 0, 0, 0]
#
# Day 13
# harvested: [12, 12, 12, 12]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [12, 12, 12, 12]
# warehouse: [0, 0, 0, 0]
#
# Day 14
# harvested: [12, 12, 12, 12]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [12, 12, 12, 12]
# warehouse: [0, 0, 0, 0]
#
# Day 15
# harvested: [25, 25, 25, 25]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [25, 25, 25, 25]
# warehouse: [0, 0, 0, 0]
#
# Day 16
# harvested: [25, 25, 25, 25]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [25, 25, 25, 25]
# warehouse: [0, 0, 0, 0]
#
# Day 17
# harvested: [25, 25, 25, 25]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [25, 25, 25, 25]
# warehouse: [0, 0, 0, 0]
#
# Day 18
# harvested: [25, 25, 25, 25]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [25, 25, 25, 25]
# warehouse: [0, 0, 0, 0]
#
# Day 19
# harvested: [25, 25, 25, 25]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [25, 25, 25, 25]
# warehouse: [0, 0, 0, 0]
#
# Day 20
# harvested: [25, 25, 25, 25]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [25, 25, 25, 25]
# warehouse: [0, 0, 0, 0]
#
# Day 21
# harvested: [25, 25, 25, 25]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [25, 25, 25, 25]
# warehouse: [0, 0, 0, 0]
#
# Day 22
# harvested: [22, 22, 22, 22]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [22, 22, 22, 22]
# warehouse: [0, 0, 0, 0]
#
# Day 23
# harvested: [22, 22, 22, 22]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [22, 22, 22, 22]
# warehouse: [0, 0, 0, 0]
#
# Day 24
# harvested: [22, 22, 22, 22]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [22, 22, 22, 22]
# warehouse: [0, 0, 0, 0]
#
# Day 25
# harvested: [22, 22, 22, 22]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [22, 22, 22, 22]
# warehouse: [0, 0, 0, 0]
#
# Day 26
# harvested: [22, 22, 22, 22]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [22, 22, 22, 22]
# warehouse: [0, 0, 0, 0]
#
# Day 27
# harvested: [22, 22, 22, 22]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [22, 22, 22, 22]
# warehouse: [0, 0, 0, 0]
#
# Day 28
# harvested: [22, 22, 22, 22]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [22, 22, 22, 22]
# warehouse: [0, 0, 0, 0]
#
# Day 29
# harvested: [22, 3, 22, 22]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [22, 3, 22, 22]
# warehouse: [0, 0, 0, 0]
#
# Day 30
# harvested: [22, 0, 22, 22]
# sold_market: [0, 0, 0, 0]
# sold_wholesale: [22, 0, 22, 22]
# warehouse: [0, 0, 0, 0]
#
#
#
#
#
#
# best profit: 4789.0 | temperature: 1000
# best profit: 4921.0 | temperature: 990.0
# best profit: 4968.3 | temperature: 980.1
# best profit: 5044.200000000001 | temperature: 970.299
# best profit: 5099.700000000003 | temperature: 960.59601
# best profit: 5151.900000000002 | temperature: 950.9900498999999
# best profit: 5205.300000000002 | temperature: 941.480149401
# best profit: 5307.500000000004 | temperature: 932.0653479069899
# best profit: 5315.2000000000035 | temperature: 922.74469442792
# best profit: 5379.600000000004 | temperature: 913.5172474836407
# best profit: 5422.700000000003 | temperature: 904.3820750088043
# best profit: 5454.900000000002 | temperature: 895.3382542587163
# best profit: 5491.400000000003 | temperature: 886.3848717161292
# best profit: 5534.300000000004 | temperature: 877.5210229989679
# best profit: 5539.700000000002 | temperature: 868.7458127689781
# best profit: 5576.400000000002 | temperature: 860.0583546412884
# best profit: 5596.100000000002 | temperature: 851.4577710948755
# best profit: 5603.4 | temperature: 842.9431933839268
# best profit: 5603.4 | temperature: 834.5137614500875
# best profit: 5605.200000000001 | temperature: 826.1686238355866
# best profit: 5605.200000000001 | temperature: 817.9069375972307
# best profit: 5605.200000000001 | temperature: 809.7278682212584
# best profit: 5605.200000000001 | temperature: 801.6305895390458
# best profit: 5609.7 | temperature: 793.6142836436553
# best profit: 5609.7 | temperature: 785.6781408072187
# best profit: 5614.500000000001 | temperature: 777.8213593991466
# best profit: 5614.500000000001 | temperature: 770.0431458051551
# best profit: 5614.500000000001 | temperature: 762.3427143471035
# best profit: 5614.500000000001 | temperature: 754.7192872036325
# best profit: 5615.700000000001 | temperature: 747.1720943315961
# best profit: 5642.400000000001 | temperature: 739.7003733882801
# best profit: 5642.400000000001 | temperature: 732.3033696543973
# best profit: 5642.400000000001 | temperature: 724.9803359578533
# best profit: 5642.400000000001 | temperature: 717.7305325982747
# best profit: 5642.400000000001 | temperature: 710.553227272292
# best profit: 5642.400000000001 | temperature: 703.4476949995691
# best profit: 5642.400000000001 | temperature: 696.4132180495734
# best profit: 5642.400000000001 | temperature: 689.4490858690776
# best profit: 5642.400000000001 | temperature: 682.5545950103868
# best profit: 5642.400000000001 | temperature: 675.7290490602829
# best profit: 5642.400000000001 | temperature: 668.9717585696801
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e211f778e5d2> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 profit_lsts = main()
#       5 print(len(profit_lsts))
#       6 for enum, lst in enumerate(profit_lsts):
#
# c:\Users\Magda\Desktop\semestr 5\BO2\BO2\main.py in main()
#      83     profit_lists = []
#      84
# ---> 85     # sol, profit, (num_draws, num_ok_draws), profit_list = orchard.simulated_annealing(T_start=1000, T_stop=1, iterations_in_temp=100,
#      86     #                                                                       epsilon=4, iterations_epsilon=10, alpha=0.99,
#      87     #                                                                       neighbour_type=1, initial_sol=2)
#
# c:\Users\Magda\Desktop\semestr 5\BO2\BO2\sad.py in simulated_annealing(self, T_start, T_stop, iterations_in_temp, epsilon, iterations_epsilon, alpha, neighbour_type, initial_sol)
#     184             print(f"best profit: {best_profit} | temperature: {T}")
#     185             for j in range(iterations_in_temp):
# --> 186                 candidate_sol = self.draw_solution(solution, neighbour_type)        #losowanie sąsiada z otoczenia
#     187                 candidate_sol_fun = self.calculate_objective_fun(candidate_sol)     #wyznaczenie fun celu dla wylosowanego
#     188                 delta = candidate_sol_fun - self.calculate_objective_fun(solution)  #zmiana wart funkcji celu pomiędzy starym a nowym rozw
#
# c:\Users\Magda\Desktop\semestr 5\BO2\BO2\sad.py in draw_solution(self, initial_solution, neighbour_type)
#     123             sol = neighbour(initial_solution)
#     124             self.num_draws += 1
# --> 125             if self.check_if_sol_acceptable(sol):
#     126                 self.num_ok_draws += 1
#     127                 return sol
#
# c:\Users\Magda\Desktop\semestr 5\BO2\BO2\sad.py in check_if_sol_acceptable(self, solution)
#     592         #three = check_minimum_amount_sold(solution, self.fruit_types)
#     593         four = check_warehouse_limits(solution, self.warehouse_capacity)
# --> 594         five = check_if_warehouse_sold(solution)
#     595         six = check_if_today_amount_correct(solution)
#     596         seven = check_if_non_negative(solution)
#
# c:\Users\Magda\Desktop\semestr 5\BO2\BO2\model_limits.py in check_if_warehouse_sold(solution)
#     137         if i > 0:
#     138             prev_warehouse = sum(solution.days[i - 1].warehouse)
# --> 139             today_sold = sum(day.sold_market) + sum(day.sold_wholesale)
#     140             if today_sold < prev_warehouse:
#     141                 # Jeśli sprzedano mniej niż poprzedniego dnia
#
# KeyboardInterrupt:
